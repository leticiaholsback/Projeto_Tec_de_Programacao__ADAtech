# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiaholsback/Projeto-T-cnicas-de-Programa-o-I/blob/main/AdaTech_Dados_Projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atenção nos comentários da próxima célula
#
# _Usando jupyter no ambiente local certifique-se de instalar o python corretamente e instalar as bibliotecas_

# %%
#Importa o pandas
import pandas as pd
#Importa o numpy
import numpy as np

#Importa o drive do google colab (TIRE O COMENTARIO DA LINHA ABAIXO PARA USAR NO COLAB)
#from google.colab import drive

#Monta o drive (TIRE O COMENTARIO DA LINHA ABAIXO PARA USAR NO COLAB)
#drive.mount('/content/drive')

#Especifica o caminho do csv no drive (TIRE O COMENTARIO DA LINHA ABAIXO PARA USAR NO COLAB)
#caminho_csv = ("/content/drive/MyDrive/Colab Notebooks/Relatorio_Cursos_Bolsistas.csv")

#Especifica o caminho do csv no AMBIENTE LOCAL (COMENTE A LINHA ABAIXO PARA USAR NO COLAB)
caminho_csv = ("Relatorio_Cursos_Bolsistas.csv")

#Lê o csv e atribui o valor df a ele
df = pd.read_csv(caminho_csv)
#Faz uma cópia do dataframe
df1 = df.copy()

# %%
#visualizando todo o banco de Dados
df1
# Out:
#     NOME_SUBTIPO_DE_CURSOS  CODIGO_CURSO                            CURSO  \
# 0                Graduação             6                       Enfermagem
# 1                Graduação            57                        Marketing
# 2                  Técnico            18  Técnico em Nutrição e Dietética
# 3                Graduação            50                    ADMINISTRAÇÃO
# 4                  Técnico            51              Técnico em Comércio
# ..                     ...           ...                              ...
# 806                Técnico        232050    Técnico em Cuidados de Idosos
# 807                Técnico            51              Técnico em Comércio
# 808                Técnico        378732        TÉCNICO EM DESIGN GRÁFICO
# 809                Técnico           131            Técnico em Artesanato
# 810                Técnico            56             Técnico em Logística
#
#                EIXO_TECNOLOGICO           MODALIDADE  CARGA_HORARIA_CURSO  \
# ...

# %% [markdown]
# Conhecendo o Banco de Dados com alguns comandos da biblioteca Pandas

# %%
#visualizando as primeiras linhas
df1.head()
# Out:
#   NOME_SUBTIPO_DE_CURSOS  CODIGO_CURSO                            CURSO  \
# 0              Graduação             6                       Enfermagem
# 1              Graduação            57                        Marketing
# 2                Técnico            18  Técnico em Nutrição e Dietética
# 3              Graduação            50                    ADMINISTRAÇÃO
# 4                Técnico            51              Técnico em Comércio
#
#     EIXO_TECNOLOGICO           MODALIDADE  CARGA_HORARIA_CURSO SITUACAO_ATIVO  \
# 0   Ambiente e Saúde  Educação Presencial                 1200              t
# 1  Gestão e Negócios  Educação Presencial                  800              t
# 2   Ambiente e Saúde  Educação Presencial                 1200              t
# 3  Gestão e Negócios  Educação Presencial                  800              a
# 4  Gestão e Negócios                  EAD                  800              t
#
#    CODIGO_UNIDADE_DE_ENSINO  \
# 0                     47955
# ...

# %%
#para ver que tipo de dado compõe cada coluna do banco
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NOME_SUBTIPO_DE_CURSOS    811 non-null    object
#  1   CODIGO_CURSO              811 non-null    int64
#  2   CURSO                     811 non-null    object
#  3   EIXO_TECNOLOGICO          811 non-null    object
#  4   MODALIDADE                805 non-null    object
#  5   CARGA_HORARIA_CURSO       811 non-null    int64
#  6   SITUACAO_ATIVO            811 non-null    object
#  7   CODIGO_UNIDADE_DE_ENSINO  811 non-null    int64
#  8   UNIDADE_DE_ENSINO         811 non-null    object
#  9   UF                        797 non-null    object
#  10  CODIGO_MUNICIPIO          811 non-null    int64
#  11  MUNICIPIO                 811 non-null    object
#  12  INICIO                    808 non-null    float64
# ...

# %%
#visualizando os valores unicos, nesse exemplo em Eixo Tecnologico
df1['EIXO_TECNOLOGICO'].unique()
# Out:
# array(['Ambiente e Saúde', 'Gestão e Negócios',
#        'Informação e Comunicação', 'Turismo, Hospitalidade e Lazer',
#        'Desenvolvimento Educacional e Social',
#        'Produção Cultural e Design', 'Controle e Processos Industriais',
#        'Infraestrutura', 'Segurança', 'Produção Industrial',
#        'Produção Alimentícia', 'Recursos Naturais'], dtype=object)

# %%
#nunique() retorna o número total de valores únicos, diferente de unique que mostrou a o nome dos cursos
num_cursos = df1['CURSO'].nunique()
print(f"Número total de cursos: {num_cursos}")
# Out:
# Número total de cursos: 89

# %%
modalidades = df1['MODALIDADE'].unique()
print(f"Modalidades de cursos oferecidas: {modalidades}")
# Out:
# Modalidades de cursos oferecidas: ['Educação Presencial' 'EAD' nan]

# %%
#aqui temos um calculo da carga horaria por modalidade, podendo ver que existe uma carga horária bem próxima 
carga_horaria_media = df1.groupby('MODALIDADE')['CARGA_HORARIA_CURSO'].mean()
print("Carga horária média por modalidade:")
print(carga_horaria_media)
# Out:
# Carga horária média por modalidade:
# MODALIDADE
# EAD                    908.333333
# Educação Presencial    923.980424
# Name: CARGA_HORARIA_CURSO, dtype: float64

# %%
distribuicao_geografica = df1.groupby(['UF', 'MUNICIPIO']).size().reset_index(name='Quantidade de Cursos')
print("Distribuição geográfica:")
print(distribuicao_geografica)
# Out:
# Distribuição geográfica:
#      UF              MUNICIPIO  Quantidade de Cursos
# 0    AC             Rio Branco                     2
# 1    AL                 Maceió                     1
# 2    AM               Iranduba                     2
# 3    AM            Itacoatiara                     3
# 4    AM             Manacapuru                     3
# ..   ..                    ...                   ...
# 211  SP  São João da Boa Vista                     2
# 212  SP              São Paulo                    54
# 213  TO              Araguaína                     1
# 214  TO                 Palmas                     3
# 215  TO           Pedro Afonso                     7
#
# [216 rows x 3 columns]

# %%
eixo_tecn = df1.groupby('UF')['MUNICIPIO'].nunique()
eixo_tecn = eixo_tecn.sort_values(ascending=True)
eixo_tecn.plot(kind='barh',title='Distribuição Geográfica')
plt.show()

# %%
status_cursos = df1['SITUACAO_ATIVO'].value_counts()
print("Status dos cursos:")
print(status_cursos)
# Out:
# Status dos cursos:
# SITUACAO_ATIVO
# t    593
# a    218
# Name: count, dtype: int64

# %% [markdown]
# Acima percebemos que o banco nos trouxe apenas t e a, esses dados acabam sendo difíceis para analise, com isso foi identificado que a seriam para ativos e t para terminados, dessa forma vamos alterar no banco df1 para seu respectivo valor

# %%
#modificando nomes ddos valores da coluna, se eu usar o inplace já deixo salvo
df1['SITUACAO_ATIVO'].replace('t', 'Finalizado', inplace=True)
df1['SITUACAO_ATIVO'].replace('a', 'Ativo', inplace=True)

df1['SITUACAO_ATIVO'].value_counts()
# Out:
# SITUACAO_ATIVO
# Finalizado    593
# Ativo         218
# Name: count, dtype: int64

# %%
tendencia_temporal = df1.groupby('INICIO')['CURSO'].count()
print("Tendência temporal:")
print(tendencia_temporal)
# Out:
# Tendência temporal:
# INICIO
# 2020.0    182
# 2021.0    181
# 2022.0    203
# 2023.0    156
# 2024.0     86
# Name: CURSO, dtype: int64

# %% [markdown]
# # **Estatística Descritiva**

# %%
estatistica_carga_horaria = df1.groupby('EIXO_TECNOLOGICO')['CARGA_HORARIA_CURSO'].describe().round(2).reset_index()
estatistica_carga_horaria
# Out:
#                         EIXO_TECNOLOGICO  count     mean     std     min  \
# 0                       Ambiente e Saúde  170.0  1150.59  132.01   800.0
# 1       Controle e Processos Industriais   19.0  1200.00    0.00  1200.0
# 2   Desenvolvimento Educacional e Social   16.0  1075.00  191.49   800.0
# 3                      Gestão e Negócios  491.0   800.00    0.00   800.0
# 4               Informação e Comunicação   55.0  1076.36   98.06  1000.0
# 5                         Infraestrutura    7.0  1142.86   97.59  1000.0
# 6                   Produção Alimentícia    7.0   800.00    0.00   800.0
# 7             Produção Cultural e Design   13.0   984.62  190.81   800.0
# 8                    Produção Industrial   10.0   960.00  206.56   800.0
# 9                      Recursos Naturais    4.0  1200.00    0.00  1200.0
# 10                             Segurança    6.0  1200.00    0.00  1200.0
# 11        Turismo, Hospitalidade e Lazer   13.0   800.00    0.00   800.0
#
# ...

# %% [markdown]
# Com isso podemos observar as seguintes métricas por coluna:
#
# *count: O número de ocorrências (linhas) para cada grupo. Ex: temos 170 linhas no eixo tecnológico Ambiente e Saúde
#
# *mean: A média (média aritmética) da 'CARGA_HORARIA_CURSO' para cada grupo. O calculo dessa média é interedssante pois podemos ver a carga horario por eixo tecnológico
#
# *std: O desvio padrão, que mede a quantidade de variação ou dispersão dos valores de 'CARGA_HORARIA_CURSO' dentro de cada grupo. Um desvio padrão mais alto indica mais variabilidade. Abaixo , mostraremos com gráfico como se da o std
#
# min: O valor mínimo de 'CARGA_HORARIA_CURSO' dentro de cada grupo.
#
# 25%: O 25º percentil, também conhecido como primeiro quartil. É o valor abaixo do qual 25% dos dados estão.
#
# 50%: A mediana, ou o 50º percentil. É o valor do meio dos dados. Também conhecido como segundo quartil.
#
# 75%: O 75º percentil, também conhecido como terceiro quartil. É o valor abaixo do qual 75% dos dados estão.
#
# max: O valor máximo de 'CARGA_HORARIA_CURSO' dentro de cada grupo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Supondo que você já tenha o DataFrame df1 carregado

# Boxplot para visualizar a distribuição da carga horária
plt.figure(figsize=(12, 6))
plt.boxplot([df1[df1['EIXO_TECNOLOGICO'] == eixo]['CARGA_HORARIA_CURSO'] for eixo in df1['EIXO_TECNOLOGICO'].unique()],
            labels=df1['EIXO_TECNOLOGICO'].unique())
plt.xticks(rotation=45, ha='right')  # Rotaciona os rótulos no eixo x para facilitar a leitura
plt.xlabel('Eixo Tecnológico')
plt.ylabel('Carga Horária do Curso')
plt.title('Boxplot da Carga Horária por Eixo Tecnológico')
plt.show()

# %% [markdown]
# Entendi que em Ambiente e Saúde temos outliers, em produção cultural e design hpa uma mediana bem significativa para analise Temos uma haste bem vísivel em Infraestrutura, mostrando dispersão dos dados. Esse gráfico se comporta de uma maneira super interessante para análise e aprendizado, pois temos muitos eixos tecnológicos que caixa mediana e hastes estão no mesmo eixo y, fazendo com que eu sugira que a distribuição está assimétrica e concentrada de carga horária para essas categorias, não havendo discrepâncias ou dispersão
#
# No código abaixo, usammos a relação de barras para nos mostrar a carga horária e o desvio padrão em cada eixo tecnológico, como dito acima, realmente, há cursos que são simétricos, não havendo discrepancia de carga horária entre eles, no grpafico temos 6 eixos com dispersão e os demais com simetria

# %%
# Calcular a média e desvio padrão para cada categoria de 'EIXO_TECNOLOGICO'
estatisticas_por_eixo = df1.groupby('EIXO_TECNOLOGICO')['CARGA_HORARIA_CURSO'].agg(['mean', 'std']).reset_index()
plt.figure(figsize=(12, 6))
plt.bar(estatisticas_por_eixo['EIXO_TECNOLOGICO'], estatisticas_por_eixo['mean'], yerr=estatisticas_por_eixo['std'], capsize=5)
plt.xticks(rotation=45, ha='right')  # Rotaciona os rótulos no eixo x para facilitar a leitura, tive ajuda no tensorflow para criar esse gráfico
plt.xlabel('Eixo Tecnológico')
plt.ylabel('Carga Horária Média')
plt.title('Média e Desvio Padrão da Carga Horária por Eixo Tecnológico')
plt.show()

# %% [markdown]
# # **Visualizações**

# %%
import matplotlib.pyplot as plt

# %%
# Exemplo de gráfico de dispersão para distribuição geográfica por UF
plt.figure(figsize=(12, 6))
plt.scatter(distribuicao_geografica['UF'], distribuicao_geografica['Quantidade de Cursos'], s=50, alpha=0.5)
plt.title('Distribuição Geográfica dos Cursos')
plt.xlabel('UF')
plt.ylabel('Quantidade de Cursos')
plt.xticks(rotation=45, ha='right')  # Rotacionar os rótulos do eixo x para melhor legibilidade
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#mostrando em ordem crescente por ano
df1['INICIO'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='INICIO'>

# %%
#vISUALIZAÇÃO EM BARRAS POR UF
df1['UF'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='UF'>

# %%
df1['QTDADE_ALUNOS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='QTDADE_ALUNOS'>

# %%
df1['INICIO'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df1['SITUACAO_ATIVO'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#Distribuição de cursos por eixo tecnológico
eixo_tecn = df1.groupby('EIXO_TECNOLOGICO')['CODIGO_CURSO'].nunique()
eixo_tecn = eixo_tecn.sort_values(ascending=True)
eixo_tecn.plot(kind='barh',title='Distribuição de Cursos por Eixo Tecnológico')
plt.xlabel('Eixo Tecnológico')
plt.ylabel('Número de Cursos')
plt.show()

# %%
top_unidades_ensino = df1.groupby('UNIDADE_DE_ENSINO')['QTDADE_ALUNOS'].sum().nlargest(10)
top_unidades_ensino.plot(kind='barh', figsize=(10, 6))
plt.title('Top 10 UNIDADE_DE_ENSINO com mais QTDADE_ALUNOS')
plt.xlabel('UNIDADE_DE_ENSINO')
plt.ylabel('QTDADE_ALUNOS')
plt.show()

# %%
top_municipios_cursos = df1['MUNICIPIO'].value_counts().nlargest(10)
top_municipios_cursos.plot(kind='barh', figsize=(10, 6))
plt.title('Top 10 MUNICIPIOS com mais CURSOS')
plt.xlabel('MUNICIPIO')
plt.ylabel('Número de CURSOS')
plt.show()

# %%
uf_desistencias = df1.groupby('UF')['DESISTENCIA'].sum()
uf_desistencias.plot(kind='bar', figsize=(10, 6))
plt.title('Desistências por UF')
plt.xlabel('UF')
plt.ylabel('Número de Desistências')
plt.show()

# %% [markdown]
# *Agora, vou plotar 3 gráficos onde mostra a quantidade de alunos com desistencia, sendo de barras empilhadas, linhas e barras

# %%
uf_desistencias_alunos = df1.groupby('UF')[['DESISTENCIA', 'QTDADE_ALUNOS']].sum()

# Plota um gráfico de barras empilhadas
uf_desistencias_alunos.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Desistências e Qtde de Alunos por UF')
plt.xlabel('UF')
plt.ylabel('Quantidade')
plt.show()

# %%
uf_desistencias_alunos = df1.groupby('UF')[['DESISTENCIA', 'QTDADE_ALUNOS']].sum()

uf_desistencias_alunos.plot(kind='bar', figsize=(12, 6))
plt.title('Qtde de Alunos e Desistências por UF')
plt.show()

# %%
ax = uf_desistencias_alunos.plot(kind='bar', figsize=(12, 6))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

#aqui pedi ajuda para outra pessoa que me explicou o seguinte:
#ax.annotate é para inserir anotações no gráfico
#str(p.get_height())aqui mostra os valores na altura (Y)
#textcoords='offset points' as coordenadas dos valores

# %%
uf_desistencias_alunos = df1.groupby('UF')[['DESISTENCIA', 'QTDADE_ALUNOS']].sum()

fig, ax1 = plt.subplots(figsize=(10, 6))

# QTDADE_ALUNOS
color = 'tab:blue'
ax1.set_xlabel('UF')
ax1.set_ylabel('Qtde de Alunos', color=color)
ax1.bar(uf_desistencias_alunos.index, uf_desistencias_alunos['QTDADE_ALUNOS'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

#linha de DESISTENCIA
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Desistências', color=color)
ax2.plot(uf_desistencias_alunos.index, uf_desistencias_alunos['DESISTENCIA'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
plt.show()

# %%
#linha o valor máximo é +- 131 e em barras próximo de 3500

# %% [markdown]
# ## Código criado para uso de Dicionário

# %%
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
ofertas = [
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO ANHANGUERA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UniEnsino', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE ANHANGUERA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PROMOVE', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE COMUNITARIA EFAPI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario de Excelência Eniac', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CESUMAR', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario CEUNI FAMETR', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO DISTRITO FEDERAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE QI BRASIL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE METROPOLITANA DO CEARA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DESCOMPLICA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE SETE LAGOAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'ESCOLA SUPERIOR NACIONAL DE SEGUROS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Uniao das Americas Descomplica', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CRUZEIRO DO SUL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DAS FACULDADES METROPOLITANAS UNIDAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO GAMA E SOUZA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO NORTE', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO DISTRITO FEDERAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE VOLTA REDONDA (UNIFOA)', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE SENAC', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Fametro', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DO NOROESTE DE MINAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE ENSINO SUPERIOR PELEGRINO CIPRIANI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO MAURICIO DE NASSAU', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE ACESITA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE CNEC RIO DAS OSTRAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DO VALE DO JAGUARIBE', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'FACULDADE JARDINS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE DO OESTE DE SANTA CATARINA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CRUZEIRO DO SUL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO METODISTA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Universidade Universus Veritas Guarulhos', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE VIA SAPIENS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE SANTA MARCELINA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE CIENCIAS SOCIAIS APLICADAS DE SINOP', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO CENTRAL PAULISTA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE DA AMAZONIA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CIDADE DE SAO PAULO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITÁRIO FILADELFIA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE BOTUCATU', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO ESPIRITO SANTO', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADES INTEGRADAS SAO PEDRO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO ATENAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE DO OESTE DE SANTA CATARINA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Uniao das Americas Descomplica', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE UNIFAMETRO CASCAVEL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Universidade Universus Veritas Guarulhos', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CESUMAR', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE CRUZEIRO DO SUL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO SUL DE MINAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE AMERICANA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Uniao das Americas Descomplica', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UniEnsino', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNICATOLICA', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'ULBRA CACHOEIRA DO SUL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'Centro Universitario de Excelencia', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario de Excelencia', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO FILADELFIA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE MURIALDO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Uniao das Americas Descomplica', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Universidade Universus Veritas Guarulhos', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE BRAZ CUBAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTEGRADO DE CAMPO MOURAO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO ANHANGUERA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO ESPIRITO SANTO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UniEnsino', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Universidade Universus Veritas Guarulhos', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE ANHANGUERA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE DE UBERABA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO IMEPAC', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PROMOVE', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE UNIFAMETRO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE CIENCIAS HUMANAS ESUDA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DESCOMPLICA', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO UNIFTEC', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UniEnsino', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE MURIALDO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO SUL DE MINAS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE CIENCIAS E EMPREENDEDORISMO', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE CRUZEIRO DO SUL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'FACULDADE QI BRASIL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO FACENS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE SETE LAGOAS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE JOAO PESSOA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTEGRADO DE CAMPO MOURAO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario Uniao das Americas Descomplica', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'Centro Universitario Funorte', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DESCOMPLICA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE CIENCIAS E EMPREENDEDORISMO', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UNIVERSIDADE METODISTA DE PIRACICABA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO UNIRB', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE JARDINS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Centro Universitario de Excelencia', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO DISTRITO FEDERAL', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'UniEnsino', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'FACULDADE TRES MARIA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE DE AMERICANA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CESUMAR', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'FACULDADE DE TECNOLOGIA ALTOMEDIO SAO FRANCISCO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADES INTEGRADAS HELIO ALONSO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO FILADELFIA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO INTERNACIONAL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CESUMAR', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE PITAGORAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO FAEL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DO NORTE', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE CESUMA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO METODISTA', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'Faculdades Sulamerica Bahia', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE GOIAS', 'ano': 2022, 'modalidade': 'ead'},
    {'instituicao': 'CENTRO UNIVERSITARIO LEONARDO DA VINCI', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'CENTRO UNIVERSITARIO DE CIENCIAS E EMPREENDEDORISMO', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'FACULDADE TRES MARIAS', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE LUTERANA DO BRASIL', 'ano': 2022, 'modalidade': 'presencial'},
    {'instituicao': 'UNIVERSIDADE DA AMAZONIA', 'ano': 2022, 'modalidade': 'ead'},
]

def estatisticas_ofertas_por_modalidade(ofertas, ano, modalidade):
    ofertas_filtradas = [oferta for oferta in ofertas if oferta['ano'] == ano and oferta['modalidade'] == modalidade]

    if not ofertas_filtradas:
        return None  # Caso não haja ofertas para o ano e modalidade especificados

    contagem_por_instituicao = Counter(oferta['instituicao'] for oferta in ofertas_filtradas)

    # Converter dados para DataFrame do pandas
    dados = pd.DataFrame.from_dict(contagem_por_instituicao, orient='index', columns=['Contagem'])

    # Plotar gráfico de barras usando matplotlib
    dados.plot(kind='barh', figsize=(15, 15), legend=False) # aqui e mudo o tamanho no gráfico
    plt.title(f'Estatísticas de Ofertas por Modalidade - Ano {ano} - Modalidade {modalidade}')
    plt.xlabel('Instituição')
    plt.ylabel('Contagem')
    plt.show()

# Exemplo de uso
estatisticas_ofertas_por_modalidade(ofertas, 2022, 'presencial')

# %%
def estatisticas_ofertas_por_modalidade(ofertas, ano, modalidade):
    ofertas_filtradas = [oferta for oferta in ofertas if oferta['ano'] == ano and oferta['modalidade'] == modalidade]

    contagem_por_instituicao = {}
    for oferta in ofertas_filtradas:
        instituicao = oferta['instituicao']
        contagem_por_instituicao[instituicao] = contagem_por_instituicao.get(instituicao, 0) + 1

    dados = pd.DataFrame.from_dict(contagem_por_instituicao, orient='index', columns=['Contagem'])

    # 10 primeiras instituições
    top_10_instituicoes = dados.nlargest(10, 'Contagem')

    # Plotar gráfico de barras usando matplotlib
    top_10_instituicoes.plot(kind='barh', figsize=(15, 15), legend=False)
    plt.title(f'Estatísticas de Ofertas por Modalidade - Ano {ano} - Modalidade {modalidade}')
    plt.xlabel('Instituição')
    plt.ylabel('Contagem')
    plt.show()

# Exemplo de uso
estatisticas_ofertas_por_modalidade(ofertas, 2022, 'presencial')

# aqui ja gera um gráfico estatístico das 10 primeiras instituiçoes

# %%
# Filtrando ofertas EAD
def estatisticas_ofertas_por_modalidade(ofertas, ano, modalidade):
    ofertas_filtradas = [oferta for oferta in ofertas if oferta['ano'] == ano and oferta['modalidade'] == modalidade]

    contagem_por_instituicao = {}
    for oferta in ofertas_filtradas:
        instituicao = oferta['instituicao']
        contagem_por_instituicao[instituicao] = contagem_por_instituicao.get(instituicao, 0) + 1

    dados = pd.DataFrame.from_dict(contagem_por_instituicao, orient='index', columns=['Contagem'])

    top_10_instituicoes = dados.nlargest(10, 'Contagem')

    top_10_instituicoes.plot(kind='barh', figsize=(10, 6), legend=False)
    plt.title(f'Estatísticas de Ofertas por Modalidade - Ano {ano} - Modalidade {modalidade.upper()} - 10 Instituições com mais Ofertas no ano')
    plt.xlabel('Instituição')
    plt.ylabel('Contagem')
    plt.show()

estatisticas_ofertas_por_modalidade(ofertas, 2022, 'ead')

# %% [markdown]
# ## Voltando para uso no Banco df1

# %%
df1 = pd.DataFrame(ofertas)

top_modalidades = df['MODALIDADE'].value_counts().head(10)
top_modalidades.plot(kind='bar')
plt.show()

# %%
df1 = pd.DataFrame(ofertas)

contagem_modalidade = df['MODALIDADE'].value_counts()
contagem_modalidade.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Distribuição de Cursos por Modalidade')
plt.show()

# %% [markdown]
# Analisando por Modalidade, pudemos observar que, mesmo sendo um banco nos períodos de Pandemia e Pós Pandemia a oferta de cursos presenciais foi bem maior
